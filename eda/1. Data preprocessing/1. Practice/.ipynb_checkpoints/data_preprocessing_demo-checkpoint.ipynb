# %%
#  Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset

# with open('iris.csv') as dataset:
#     df = dataset.read()
#     print(df)

df = pd.read_csv('iris.csv')
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# #  Handling missing values

# %%
df.isnull().sum()
# df.fillna(df.mean(), inplace=True)
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %% [markdown]
# # Handling duplications (if duplication here removing....)

# %%
# df.duplicated().sum()
print(f"Number of duplicates: {df.duplicated().sum()}")
# Out:
# Number of duplicates: 3

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %%
print(f"Number of duplicates: {df.duplicated().sum()}")
# Out:
# Number of duplicates: 0

# %% [markdown]
# # Encoding categorical variables (comverting categorical variables to  numericals)

# %%
if df.select_dtypes(include = ['object']).columns.any():
    df = pd.get_dummies(df, drop_first = True)

# %% [markdown]
# #  Feature Scaling
# # Standardizing th numerical columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
numerical_features = df.select_dtypes(include = [np.number]).columns
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
scaler
# Out:
# StandardScaler()

# %%
#  Correlation matrix 
print(df.corr())
# Out:
#                                   5.1       3.5       1.4       0.2  \
# 5.1                          1.000000 -0.103591  0.870793  0.816015
# 3.5                         -0.103591  1.000000 -0.415679 -0.350436
# 1.4                          0.870793 -0.415679  1.000000  0.961405
# 0.2                          0.816015 -0.350436  0.961405  1.000000
# Iris-setosa_Iris-versicolor  0.064910 -0.468596  0.191335  0.105630
# Iris-setosa_Iris-virginica   0.638286 -0.119392  0.717524  0.766970
#
#                              Iris-setosa_Iris-versicolor  \
# 5.1                                             0.064910
# 3.5                                            -0.468596
# 1.4                                             0.191335
# 0.2                                             0.105630
# Iris-setosa_Iris-versicolor                     1.000000
# Iris-setosa_Iris-virginica                     -0.512934
#
#                              Iris-setosa_Iris-virginica
# ...

# %%
# plotting correlation matrix 
plt.figure(figsize = (12,8))
plt.title('Correlation Matrix')
sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
plt.show()
